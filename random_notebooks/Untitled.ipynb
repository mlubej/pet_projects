# %%
import geopandas as gpd

# %%
data = gpd.read_file('unbuffered.geojson')

# %%
plist = list(data['index'])

# %%
print("patch_list: [", end="")
for p in plist[:-1]:
    print(p, end=",")
print(f'{plist[-1]}]')
# Out:
# patch_list: [248,249,250,251,294,295,296,297,298,299,343,344,345,346,347,348,349,350,351,352,401,402,403,404,405,406,407,408,409,461,462,463,464,465,466,467,468,469,526,527,528,529,530,531,532,533,591,592,593,594,595,596,656,657,658,659,660,661,718,719,720,721,722,723,724,780,781,782,783,784,785,786,843,844,845,846,847,848,849,905,906,907,908,909,910,911,912,970,971,972,973,4475,4476,4477,4538,4539,4540,4541,4542,4543,4595,4596,4599,4600,4601,4602,4603,4604,4605,4606,4658,4659,4660,4661,4662,4663,4664,4665,4666,4667,4668,4669,4670,4721,4722,4723,4724,4725,4726,4727,4728,4729,4730,4731,4732,4733,4734,4784,4785,4786,4787,4788,4789,4790,4791,4792,4793,4794,4795,4796,4797,4798,4844,4845,4846,4847,4848,4849,4850,4851,4852,4853,4854,4855,4856,4857,4858,4904,4905,4906,4907,4908,4909,4910,4911,4912,4913,4914,4915,4916,4917,4918,4919,4920,4965,4966,4967,4968,4969,4970,4971,4972,4973,4974,4975,4976,4977,4978,4979,4980,4981,5030,5031,5032,5033,5034,5035,5036,5037,5038,5039,5040,5041,5042,5043,5
# ...
